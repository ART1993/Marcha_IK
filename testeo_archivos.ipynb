# %%
from Testeo.corrected_test_suite import main
main()
# Out:
# 🎯 CORRECTED BALANCE & SQUAT TEST SUITE
# ...
# Choose testing option:
# 1. Run corrected full test suite
# 2. Quick PAM debug test only
# 3. Help with corrections
# ...
# 🛠️ CORRECTED TEST SUITE FOR BALANCE & SQUAT SYSTEM
# ...
# Este test suite incluye las correcciones para:
#   ✅ PAM McKibben Physics - Inicialización corregida
#   ✅ Trainer Configuration - Atributos arreglados
#   🧪 Tests adicionales de integración
# ...
#
# 🧪 Running: PAM McKibben Physics (CORRECTED)
# ------------------------------------------------------------
# DEBUG PAM: pressure=303975, epsilon=0.150,force_factor=0.933, a=3.000, b=2.000
#    ✅ PASSED: Force = 356.2N at 3.0atm, 15.0% contraction
#    🐛 Debug: epsilon_max=0.184, a=3.000, b=2.000
#
# 🧪 Running: Trainer Configuration (CORRECTED)
# ------------------------------------------------------------
# 🤖 Simplified Balance & Squat Trainer initialized
#    Target: Balance + Sentadillas con 6 PAMs
#    Timesteps: 1,000
#    Parallel envs: 1
#    Learning rate: 0.0003
# ...

# %%
from Testeo.contact_aware_expert_test import run_contact_aware_expert_verification
run_contact_aware_expert_verification()
# Out:
# 🎯 VERIFICACIÓN DE ACCIONES EXPERTAS - Post-Contacto
# ...
# Esta verificación implementa la solución elegante:
# 1. Robot se estabiliza naturalmente (standing position)
# 2. Detecta contacto bilateral automáticamente
# 3. Solo ENTONCES empieza a medir rendimiento
# ...
# 🦶 TEST DE BALANCE - Solo Después del Contacto
# ...
# Estrategia: El robot se estabiliza naturalmente, luego medimos rendimiento
# Duración objetivo DESPUÉS del contacto: 20s
# ...
# 🎯 Simplified Balance & Squat Reward System initialized
#    Focus: Height + Orientation + Stability
#    Weights: {'survival': 1.0, 'height': 3.0, 'orientation': 4.0, 'stability_zmp': 2.0, 'contact': 2.0, 'velocity_penalty': 1.0, 'pam_efficiency': 1.0}
# 🤖 Simplified Balance & Squat Environment initialized
#    Action space: 6 PAM pressures
#    Observation space: 16 elements
#    Target: Balance + Sentadillas
# ✅ Simple Balance & Squat Environment created
#    Focus: Balance de pie + Sentadillas
#    Action space: (6,)
#    Observation space: (16,)
# ...

# %%
from Testeo.expert_action_test import run_expert_verification
run_expert_verification()
# Out:
# 🎯 EXPERT ACTION VERIFICATION SUITE
# ...
# Este test verifica que las acciones expertas funcionan antes del entrenamiento
# ...
# 🎯 TESTING EXPERT BALANCE BEHAVIOR
# ...
# Objetivo: Verificar que el robot puede mantener balance usando acciones expertas
# Duración: 20 segundos
# ...
# 🎯 Simplified Balance & Squat Reward System initialized
#    Focus: Height + Orientation + Stability
#    Weights: {'survival': 1.0, 'height': 3.0, 'orientation': 4.0, 'stability_zmp': 2.0, 'contact': 2.0, 'velocity_penalty': 1.0, 'pam_efficiency': 1.0}
# 🤖 Simplified Balance & Squat Environment initialized
#    Action space: 6 PAM pressures
#    Observation space: 16 elements
#    Target: Balance + Sentadillas
# ✅ Simple Balance & Squat Environment created
#    Focus: Balance de pie + Sentadillas
#    Action space: (6,)
#    Observation space: (16,)
# 🎯 Simplified Balance & Squat Controller initialized
#    Available actions: BALANCE_STANDING, SQUAT
# ✅ Balance & Squat Controller created
# ...
