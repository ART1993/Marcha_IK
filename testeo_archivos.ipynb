# %%
from Testeo.comprehensive_testing_suite import select_tests
select_tests()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from Testeo.comprehensive_testing_suite import select_tests
#       2 select_tests()
#
# File c:\Users\Alejandro\Documents\Master_IA\TFM\soft_robots\programacion_soft_robotic\Marcha_IK\Testeo\comprehensive_testing_suite.py:20
#      18 from Controlador.discrete_action_controller import create_balance_squat_controller
#      19 from Controlador.discrete_action_controller import ActionType
# ---> 20 from Gymnasium_Start.Simple_BalanceSquat_BipedEnv import create_simple_balance_squat_env
#      21 from Gymnasium_Start.Simplified_BalanceSquat_Trainer import create_balance_squat_trainer, train_balance_and_squats
#      22         #from Simplified_BalanceSquat_PAMEnv import create_simple_balance_squat_env
#      23         #from Simplified_BalanceSquat_Controller import create_balance_squat_controller
#      24
#      25 # Add project paths (adjust as needed)
#
# File c:\Users\Alejandro\Documents\Master_IA\TFM\soft_robots\programacion_soft_robotic\Marcha_IK\Gymnasium_Start\Simple_BalanceSquat_BipedEnv.py:15
#      13 from Archivos_Apoyo.Configuraciones_adicionales import PAM_McKibben
#      14 from Archivos_Apoyo.ZPMCalculator import ZMPCalculator
# ---> 15 from Archivos_Mejorados.Simplified_BalanceSquat_RewardSystem import Enhanced_ImproveRewardSystem
#      16 from Archivos_Apoyo.Pybullet_Robot_Data import PyBullet_Robot_Data
#      18 class Simple_BalanceSquat_BipedEnv(gym.Env):
#
# ImportError: cannot import name 'Enhanced_ImproveRewardSystem' from 'Archivos_Mejorados.Simplified_BalanceSquat_RewardSystem' (c:\Users\Alejandro\Documents\Master_IA\TFM\soft_robots\programacion_soft_robotic\Marcha_IK\Archivos_Mejorados\Simplified_BalanceSquat_RewardSystem.py)

# %%
from Testeo.testing_system import main_test
main_test(command="quick")
