# %%
# !tensorboard --logdir="logs_balance_squat" --port=8892

# %%
from Squat_Controller.squat_controller import create_squat_controller, SquatConfig

# Crear controlador (detecta tu modelo automáticamente)
controller = create_squat_controller()

# Una sentadilla
if controller.start_squat_session():
    metrics = controller.execute_single_squat()
    print(f"Calidad: {metrics.quality.value}")
    controller.stop_squat_session()
    
controller.close()
# Out:
# 🏗️ Initializing simplified squat environment...
# ⚠️ Logging not initialized, using regular print: 🤖 Simplified Balance & Squat Environment initialized
# ⚠️ Logging not initialized, using regular print: 🤖 Environment initialized - Systems initiate in reset
# 🧠 Loading trained RL model...
# ✅ RL model loaded successfully
# ✅ Components initialized (Simplified Architecture)
# 🏋️ SquatController (Simplified) initialized successfully
#    Model: best_model.zip
#    Target depth: 0.7m
#    Architecture: RL Model Only (Simplified)
# 🚀 Starting squat session...
# ✅ Ultra-Simple Reward System initialized
# ✅ Ultra-Simple Action Selector initialized
#    Starting expert help: 80%
#    Available actions: ['balance', 'squat']
# 🎯 Simplified ZMP Calculator initialized
#    Stability margin: 0.15m
#    COM height estimate: 1.0m
# ⚠️ Logging not initialized, using regular print: 🔧 Contact friction configured:
# ⚠️ Logging not initialized, using regular print:    Feet: μ=1.2 (high grip)
# ...

# %%
# Configuración personalizada
config = SquatConfig(
    target_depth=0.7,      # Profundidad objetivo
    hold_duration=2.0,     # Tiempo en posición baja
    max_squat_duration=15.0 # Tiempo máximo por sentadilla
)

controller = create_squat_controller(config=config)

# 5 sentadillas con descanso
metrics_list = controller.execute_squat_sequence(
    num_squats=5,
    rest_time=3.0
)

# Estadísticas completas
stats = controller.get_performance_stats()
print(f"Tasa de éxito: {stats['success_rate']:.1%}")
