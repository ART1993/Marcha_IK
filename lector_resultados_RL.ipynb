# %%
# !tensorboard --logdir="logs_lift_leg" --port=8892
# Out:
# C:\Users\Alejandro\anaconda3\envs\GymnasiumRobot\lib\site-packages\tensorboard\default.py:30: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# TensorFlow installation not found - running with reduced feature set.
# E1107 18:22:35.520733  5732 program.py:300] TensorBoard could not bind to port 8892, it was already in use
# ERROR: TensorBoard could not bind to port 8892, it was already in use

# %%
import pybullet as p, pybullet_data
from Archivos_Apoyo.Pybullet_Robot_Data import PyBullet_Robot_Data
client=p.connect(p.DIRECT)
p.setAdditionalSearchPath(pybullet_data.getDataPath())
plane = p.loadURDF("plane.urdf")
robot_list=("2_legged_human_like_robot20DOF","2_legged_human_like_robot12DOF","2_legged_human_like_robot24DOF", "/cassie_description/urdf/cassie_v4",
            "Black_bird/urdf/blackbird")
robot_name=robot_list[4]
robot = p.loadURDF(f"Robots_Versiones/{robot_name}.urdf", [0,0,2.21], useFixedBase=True)
num_joints=p.getNumJoints(robot)
informacion_robot=PyBullet_Robot_Data(robot)
joint_info=informacion_robot._get_joint_info

link_info = informacion_robot._get_link_info
p.disconnect(client)

# %%
from json import dumps
json_joint_info=dumps(joint_info, indent=4)
json_link_info=dumps(link_info,indent=4)
robot_name="blackbird"
with open(f"JSON_Info_Robot/{robot_name}.json","w") as f:
    f.write(json_joint_info)
with open(f"JSON_Info_Robot/{robot_name}_links.json","w") as f:
    f.write(json_link_info)

# %%
from json import load
with open(f"JSON_Info_Robot/{robot_name}.json","r") as f:
    json_file=load(f)
with open(f"JSON_Info_Robot/{robot_name}_links.json","r") as f:
    json_file_link=load(f)

# %%
json_file_link[str(0)]
